# %%
# !git clone https://github.com/KaiyangZhou/Dassl.pytorch.git
# Out:
# Cloning into 'Dassl.pytorch'...
# remote: Enumerating objects: 2477, done.
# remote: Counting objects: 100% (993/993), done.
# remote: Compressing objects: 100% (326/326), done.
# remote: Total 2477 (delta 769), reused 830 (delta 667), pack-reused 1484
# Receiving objects: 100% (2477/2477), 435.40 KiB | 4.27 MiB/s, done.
# Resolving deltas: 100% (1650/1650), done.

# %%
# %cd Dassl.pytorch/
# !pwd
# Out:
# /kaggle/working/Dassl.pytorch
# /kaggle/working/Dassl.pytorch

# %%
# Install torch (requires version >= 1.8.1) and torchvision
# Please refer to https://pytorch.org/ if you need a different cuda version
# !pip install torch torchvision torchaudio


# Install dependencies
# !pip install -r requirements.txt

# Install this library (no need to re-build if the source code is modified)
# !python setup.py develop
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.3/185.3 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 57.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7029 sha256=975619eca84aff1b4a06f5c3f48173d9b0dc262fb5b4f22d5391b0b0fdf78fa1
# ...

# %%
# %cd ..
# Out:
# /kaggle/working

# %%
# !git clone https://github.com/BrandnerKasper/MP_CustomCoOp.git
# Out:
# Cloning into 'MP_CustomCoOp'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 215 (delta 110), reused 179 (delta 76), pack-reused 0
# Receiving objects: 100% (215/215), 61.89 KiB | 2.95 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %%
# %cd MP_CustomCoOp/
# Out:
# /kaggle/working/MP_CustomCoOp

# %%
# !pip install -r requirements.txt

# %%
# !pip install open_clip_torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 15.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-q1f8hsj4
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-q1f8hsj4
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369501 sha256=df9720f14391f8bb75eb547f792520a4a05b1d548bf0f8d275acbb6bf21b4ce0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ixq5shg0/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# ...

# %%
cd kaggle/working/MP_CustomCoOp/
# Out:
# [Errno 2] No such file or directory: 'kaggle/working/MP_CustomCoOp/'
# /kaggle/working/MP_CustomCoOp

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip install transformers==4.30.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 44.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.33.0
#     Uninstalling transformers-4.33.0:
#       Successfully uninstalled transformers-4.33.0
# ...

# %%
# !python list_available_models.py
# Out:
# All available clip models with different configs (different number of epochs) (no different pretrained tags!)
# rn50, rn50_ep50, rn50_ep100
# rn101, rn101_ep50
# vit_b16, vit_b16_ep50, vit_b16_ep100
# vit_b32, vit_b32_ep50
#
# All available open clip models with different configs (different number of epochs) and different pretrained tags!
# backbone: ('rn50', 'rn50_ep50', 'rn50_ep100'), pretrained: ['openai', 'yfcc15m', 'cc12m']
# backbone: ('rn101', 'rn101_ep50'), pretrained: ['openai', 'yfcc15m']
# backbone: ('vit_b16', 'vit_b16_ep50', 'vit_b16_ep100'), pretrained: ['openai', 'laion400m_e31', 'laion400m_e32', 'laion2b_s34b_b88k', 'datacomp_l_s1b_b8k', 'commonpool_l_clip_s1b_b8k', 'commonpool_l_laion_s1b_b8k', 'commonpool_l_image_s1b_b8k', 'commonpool_l_text_s1b_b8k', 'commonpool_l_basic_s1b_b8k', 'commonpool_l_s1b_b8k']
# ...

# %%
# !python train.py "../../input/dataset" rn50 --shots 16 --open_Clip
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# arguments: backbone=rn50, config_file=configs/trainers/CoOp/rn50.yaml, dataset_config_file=configs/datasets/caltech101.yaml, eval_only=False, head=, load_epoch=None, model_dir=, no_train=False,  opts: ['TRAINER.COOP.N_CTX', '16', 'TRAINER.COOP.CSC', 'False', 'TRAINER.COOP.CLASS_TOKEN_POSITION', 'end', 'DATASET.NUM_SHOTS', '16'], output_dir=output/Caltech, resume=, root=../../input/dataset, seed=-1, source_domains=None, target_domains=None, trainer=CoOp, transforms=None, open_clip=True, pretrained=openai
# Setting fixed seed: 1
# ***************
# ** Arguments **
# ***************
# backbone: rn50
# config_file: configs/trainers/CoOp/rn50.yaml
# csc: False
# ctp: end
# dataset_config_file: configs/datasets/caltech101.yaml
# n_ctx: 16
# ...

# %%
# !python eval.py
# Out:
# open_clip_rn50_openai_16.txt Mean with Standard Deviation: 88.5% +- 0.7%

# %%
import shutil
shutil.rmtree("kaggle/working/MP_CustomCoOp/output/Caltech")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 import shutil
# ----> 2 shutil.rmtree("kaggle/working/MP_CustomCoOp/output/Caltech")
#
# File /opt/conda/lib/python3.10/shutil.py:715, in rmtree(path, ignore_errors, onerror)
#     713     orig_st = os.lstat(path)
#     714 except Exception:
# --> 715     onerror(os.lstat, path, sys.exc_info())
#     716     return
#     717 try:
#
# File /opt/conda/lib/python3.10/shutil.py:713, in rmtree(path, ignore_errors, onerror)
#     710 # Note: To guard against symlink races, we use the standard
#     711 # lstat()/open()/fstat() trick.
#     712 try:
# --> 713     orig_st = os.lstat(path)
#     714 except Exception:
#     715     onerror(os.lstat, path, sys.exc_info())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kaggle/working/MP_CustomCoOp/output/Caltech'
